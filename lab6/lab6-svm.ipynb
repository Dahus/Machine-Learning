# %% [markdown]
# В этом задании мы должны научить машину понимать тексты. В файле recs.txt находятся отзывы о разных фильмах. Наша модель машинного обучения должна проанализировать отзыв и ответить на простой вопрос: понравился ли пользователю просмотренный фильм.
#
# Подключите необходимые для работы пакеты: pandas as pd, numpy as np, nltk, re, все функции из sklearn

# %%
import pandas as pd
import numpy as np
import nltk
import re
from sklearn import *

# %% [markdown]
# Увеличьте ширину выводимой информации в DataFrame (на это понадобится для показа текстов отзывав):
# pd.set_option('max_colwidth',600)

# %%
pd.set_option('max_colwidth',600)

# %% [markdown]
# Прочтите данные из файла recs.txt, в качестве разделителя (параметр sep) там выступает строка "\\-\\-\\|\\|\\|\\-\\-", кодировка (параметр encoding) - 'utf-8'.
#
# Выведите три первых строки таблицы. Какое отношение (Sentiment) у авторов отзывов к просмотренным фильмам?

# %%
data = pd.read_csv(r'C:\Users\user\Desktop\Машинное обучение\lab6\recs.txt',  encoding = 'utf-8', engine = 'python', sep='\-\-\|\|\|\-\-')
data.head(3)
# Out:
#    Sentiment                                         URL  \
# 0         -1     kinopoisk.ru/user/72383/comment/846161/
# 1          1    kinopoisk.ru/user/697175/comment/805374/
# 2          1  kinopoisk.ru/user/1335875/comment/2079675/
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Text
# 0  На самых первых титрах у меня появилось абсолютно твёрдое и непоколебимое ощущение, что я смотрю совершено детский фильм, в духе «Детей шпионов», иначе как объяснить наличие в начальных титрах техно-музыки и огромнейшего, просто колоссальнейшего наличия компьютерной графики, уровня приставок фирмы Sega. Если кто из вас по детству удосужился сыграть в видео-игру по мотивам мультфильма «Король-лев», адаптированную специально для этого платформера, тот прекрасно меня поймёт. Для полноты картины не хватает только мангуста Димона, который выдал бы в камеру памятное «It starts!». Хотя в данном ф...
# 1  Вы знаете, неожиданно хороший фильм. Я не большой любитель фильмов такого жанра, но этот мне очень понравился, совсем не ожидала. Придраться, как бы сильно ни хотелось это сделать, не к чему: Сюжет необычный, непривычный, оригинальный и оторваться от просмотра практически невозможно. Весь фильм проходит в движении: вечно что-то случается, открываются какие-то тайны, всевозможные неожиданные повороты и напряженные моменты. Как я уже сказала, если начнете смотреть этот фильм, остановиться уже не сможете. Я, к примеру, просто не смогла оторваться, практически прилипла к экрану. Персонажи - за...
# 2  Да, этот фильм такой, что всё, что там покажут, можно было угадать заочно. Достаточно было посмотреть на постер и прочесть название. Однако решил ввязаться в просмотр. В принципе, могу сказать, что не жалею времени, потраченного на это кино. Хоть это и не выдающаяся картина, было увлекательно посмотреть на приятных глазу актёров, а временами даже смешно. Это мелодрама с элементами комедии. Или любовная комедия. Или комедия с девичьим уклоном. Однако, думаю, и парням будет посмотреть что. В дебюте так вообще главные герои занимаются сексом везде и в каждом месте, словно слетевшие с катушек....

# %% [markdown]
# Чтобы преобразовать тексты в наборы признаков методом bag-of-words мы должны сначала профильтровать текст, оставив только значащие слова. Скачайте из корпуса набор незначащих слов для фильтрации командой nltk.download()  (в появившемся окне вкладка Corpora, пункт stopwords).

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# Импортируйте список незначащих слов командами
# ```python
# from nltk.corpus import stopwords
# stopwords = set(stopwords.words("russian"))
# ```
# и выведите его на экран.

# %%
from nltk.corpus import stopwords
stopwords = set(stopwords.words("russian"))

# %% [markdown]
# Определите функцию фильтрации текста:
# ```python
# def review_to_words( review_text ):
#     review_text = review_text.replace('ё','е')
#     review_text = review_text.replace('Ё','Е')
#     # 1. Удаляем все, кроме букв
#     letters_only = re.sub("[^а-яА-Я]", " ", review_text)
#     # 2. Делаем все буквы строчными и создаем массив слов
#     words = letters_only.lower().split()
#     # 3. Удаляем незначащие слова
#     meaningful_words = [w for w in words if not w in stopwords]
#     # 4. Формируем текст, объединяя слова через пробел
#     return( " ".join( meaningful_words ))
# ```

# %%
def review_to_words( review_text ):
    review_text = review_text.replace('ё','е')
    review_text = review_text.replace('Ё','Е')
    # 1. Удаляем все, кроме букв
    letters_only = re.sub("[^а-яА-Я]", " ", review_text) 
    # 2. Делаем все буквы строчными и создаем массив слов
    words = letters_only.lower().split()                             
    # 3. Удаляем незначащие слова
    meaningful_words = [w for w in words if not w in stopwords]
    # 4. Формируем текст, объединяя слова через пробел
    return( " ".join( meaningful_words ))

# %% [markdown]
# Скопируйте базу данных отзывов с помощью метода copy() в новую переменную и примените к отзывам функцию фильтрации: .apply(lambda s: review_to_words(s)).
#
# Выведите на экран первые три строчки преобразованной базы данных

# %%
type(data)
data2 = data.copy()
data2['Text']= data2['Text'].apply(lambda s: review_to_words(s))
data2.head(3)
# Out:
#    Sentiment                                         URL  \
# 0         -1     kinopoisk.ru/user/72383/comment/846161/
# 1          1    kinopoisk.ru/user/697175/comment/805374/
# 2          1  kinopoisk.ru/user/1335875/comment/2079675/
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Text
# 0  самых первых титрах появилось абсолютно твердое непоколебимое ощущение смотрю совершено детский фильм духе детей шпионов иначе объяснить наличие начальных титрах техно музыки огромнейшего просто колоссальнейшего наличия компьютерной графики уровня приставок фирмы детству удосужился сыграть видео игру мотивам мультфильма король лев адаптированную специально платформера прекрасно поймет полноты картины хватает мангуста димона который выдал камеру памятное хотя данном фильме фильму подошло сидишь неволей думаешь попал фильм адресованный поколению ясельной группы детского сада сюжет большему с...
# 1  знаете неожиданно хороший фильм большой любитель фильмов такого жанра очень понравился ожидала придраться сильно хотелось это сделать чему сюжет необычный непривычный оригинальный оторваться просмотра практически невозможно весь фильм проходит движении вечно случается открываются какие тайны всевозможные неожиданные повороты напряженные моменты сказала начнете смотреть фильм остановиться сможете примеру просто смогла оторваться практически прилипла экрану персонажи замечательные помощи актеров которых подобрали ким бейсингер просто шикарна хотя видеть роли жертвы очень непривычно равно здо...
# 2  фильм покажут угадать заочно достаточно посмотреть постер прочесть название однако решил ввязаться просмотр принципе могу сказать жалею времени потраченного это кино это выдающаяся картина увлекательно посмотреть приятных глазу актеров временами смешно это мелодрама элементами комедии любовная комедия комедия девичьим уклоном однако думаю парням посмотреть дебюте вообще главные герои занимаются сексом везде каждом месте словно слетевшие катушек эштон кутчер актер который никак профессионал сформироваться моем сознании часто картины номинируются золотую малину эффект бабочки всякий заставля...

# %% [markdown]
# Запустите преобразователь текстового признака в «bag of words» с помощью класса CountVectorizer библиотеки sklearn.feature_extraction.text.
#
# В конструкторе класса укажите параметры: analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 50000, binary = True
#
# Вызовите метод обучения (построения словаря) и преобразования текстов: fit_transform. Результат присвойте новой переменной bagOfWords.
#
# Сохраните порядок слов в словаре (метод .get_feature_names()) в переменную vocabulary.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 50000, binary = True)
bagOfWords = vectorizer.fit_transform(data2.Text)
vocabulary = vectorizer.get_feature_names_out()

# %% [markdown]
# Теперь в наших матрицах объектов-признаков 50 тысяч столбцов и в сумме 100 тысяч строк. Если 1 элемент занимает 1 байт, то суммарный объем будет 5 Гб. Проверьте по диспетчеру задач (системный монитор в Linux), сколько занимает памяти ваша программа и напишите в комментариях. Все ли согласуется?

# %%
# вроде бы нет.

# %% [markdown]
# Разбейте выборку bagOfWords на две части: обучающую (строки до 50000) и проверочную (строки >= 50000). Назовите их bagOfWordsTrain и bagOfWordsTest

# %%
bagOfWordsTrain = bagOfWords[:50000]
bagOfWordsTest = bagOfWords[50000:]

# %%
data2Train = data2[:50000]
data2Test = data2[50000:]
data2Train.head(3)
# Out:
#    Sentiment                                         URL  \
# 0         -1     kinopoisk.ru/user/72383/comment/846161/
# 1          1    kinopoisk.ru/user/697175/comment/805374/
# 2          1  kinopoisk.ru/user/1335875/comment/2079675/
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Text
# 0  самых первых титрах появилось абсолютно твердое непоколебимое ощущение смотрю совершено детский фильм духе детей шпионов иначе объяснить наличие начальных титрах техно музыки огромнейшего просто колоссальнейшего наличия компьютерной графики уровня приставок фирмы детству удосужился сыграть видео игру мотивам мультфильма король лев адаптированную специально платформера прекрасно поймет полноты картины хватает мангуста димона который выдал камеру памятное хотя данном фильме фильму подошло сидишь неволей думаешь попал фильм адресованный поколению ясельной группы детского сада сюжет большему с...
# 1  знаете неожиданно хороший фильм большой любитель фильмов такого жанра очень понравился ожидала придраться сильно хотелось это сделать чему сюжет необычный непривычный оригинальный оторваться просмотра практически невозможно весь фильм проходит движении вечно случается открываются какие тайны всевозможные неожиданные повороты напряженные моменты сказала начнете смотреть фильм остановиться сможете примеру просто смогла оторваться практически прилипла экрану персонажи замечательные помощи актеров которых подобрали ким бейсингер просто шикарна хотя видеть роли жертвы очень непривычно равно здо...
# 2  фильм покажут угадать заочно достаточно посмотреть постер прочесть название однако решил ввязаться просмотр принципе могу сказать жалею времени потраченного это кино это выдающаяся картина увлекательно посмотреть приятных глазу актеров временами смешно это мелодрама элементами комедии любовная комедия комедия девичьим уклоном однако думаю парням посмотреть дебюте вообще главные герои занимаются сексом везде каждом месте словно слетевшие катушек эштон кутчер актер который никак профессионал сформироваться моем сознании часто картины номинируются золотую малину эффект бабочки всякий заставля...

# %%
x = bagOfWordsTrain
y = data2Train['Sentiment']

# %% [markdown]
# Сконструируйте машину опорных векторов svm.LinearSVC с параметрами C=1, fit_intercept=False и присвойте ее переменной SVM.
#
# Натренируйте ее на обучающей выборке и с помощью метода .score(x,y) вычислите процент правильных предсказаний для тестовой выборки.

# %%
SVM = svm.LinearSVC(C=1, fit_intercept=False)
SVM.fit(x, y)
# Out:
# LinearSVC(C=1, fit_intercept=False)

# %% [markdown]
# Подберите важность суммы нарушений C, чтобы SVM работала лучше всего

# %% [markdown]
# Выведите на экран 20 слов, которые больше всего голосуют за позитивность отзыва и 20 — за негативность вместе с соответствующими им коэффициентами натренированной линейной функции:
# ```python
# ind = np.argsort(SVM.coef_[0])
# for i in range(20):
#     print(SVM.coef_[0][ind[i]], vocabulary[ind[i]])
# print("\n")
# for i in range(20):
#     print(SVM.coef_[0][ind[-i-1]], vocabulary[ind[-i-1]])
# ```

# %%
ind = np.argsort(SVM.coef_[0])
for i in range(20):
    print(SVM.coef_[0][ind[i]], vocabulary[ind[i]])
print("\n")
for i in range(20):
    print(SVM.coef_[0][ind[-i-1]], vocabulary[ind[-i-1]])
# Out:
# -0.5651936880626255 разочарование
# -0.5404606388190908 провал
# -0.4788624280680027 рекламе
# -0.47779035602039255 ужасен
# -0.47379410613574613 надеялся
# -0.46918810045577997 разочарована
# -0.46524079366930327 скучная
# -0.4629827378769035 непонятными
# -0.46010088217249817 передачи
# -0.45178325058994445 тети
# -0.4508763160970569 отсутствует
# -0.4466498346129622 увы
# -0.4339383511059031 досмотреть
# -0.43346363019470335 советовать
# -0.42206277032088113 коротким
# -0.4174957860428542 скучный
# -0.4114678178987131 вяло
# -0.4091387883975061 затянутый
# -0.4000348814973598 досматривать
# -0.3998302914845152 отвратительно
#
#
# 0.44086663898507583 отпускает
# 0.4338905654686973 придраться
# 0.4257825633607156 отличный
# 0.4257636504856477 плавно
# 0.41233788778643765 шикарен
# 0.40723642356849205 счастья
# 0.4017616166229549 прекрасен
# 0.381913028981906 потрясающе
# 0.38085067248717913 одновременно
# 0.3792323364875582 великолепно
# 0.3751408256037174 современному
# 0.3738355466213731 оторваться
# 0.36407676235961195 великолепные
# 0.35419637893262806 замечательный
# 0.3485283248173069 великолепная
# 0.3484424205966684 браво
# 0.34717487676840747 бесит
# 0.34270322818986876 отличное
# 0.3423205926181989 гениальное
# 0.340840841755931 бурю

# %% [markdown]
# Какой коэффициент соответствует словам: 'критика', 'странно', 'понимаю', 'деньги', 'даже' и еще 5 ваших слов по выбору. За что они голосуют: позитивность или негативность отзыва?

# %%
word = ['критика', 'странно', 'понимаю', 'деньги', 'вау','супер', 'класс', 'негатив', 'грустно', 'лох']
#даже - нету такого слова
for i in word:
    print(SVM.coef_[0][np.where(vocabulary == i)[0]][0], i)
# Out:
# 0.022813817302660053 критика
# 0.1611432197936841 странно
# -0.24612942665847193 понимаю
# -0.11112362025160094 деньги
# 0.07264487909013459 вау
# 0.1440538195716704 супер
# -0.004047721227390579 класс
# -0.10731420923407989 негатив
# -0.051037741926695225 грустно
# -0.07613965023404459 лох

# %% [markdown]
# Вычислите выступы, найдите и выведете на экран отзывы с минимальным и максимальным выступом, величину выступа, величину предсказания и сентиментность отзыва. Объясните в комментариях, почему найденный отзыв имеет такой маленький выступ, а другой найденный — такой большой:
# ```python
# prediction = SVM.decision_function(bagOfWordsTest)
# margins = np.multiply(prediction, data.loc[50000:]['Sentiment'].as_matrix())
# ind = np.argsort(margins)
# i = ind[-1] + 50000
# print('Величина выступа = ', margins[ind[-1]])
# print('Величина предсказания = ', prediction[ind[-1]])
# print('Сентиментность отзыва = ', data.loc[i,'Sentiment'])
# print('\n')
# print(data.loc[i,'Text'])
# print("\n")
# i = ind[0] + 50000
# print('Величина выступа = ', margins[ind[0]])
# print('Величина предсказания = ', prediction[ind[0]])
# print('Сентиментность отзыва = ', data.loc[i,'Sentiment'])
# print('\n')
# print(data.loc[i,'Text'])
# ```
#
# Для объяснения отступов вам возможно пригодится код, который печатает коэффициенты w<sub>i</sub> линейной функции, значения соответствующих признаков и соответствующие слова. И все это делается в порядке убывания модуля произведения w<sub>i</sub>x<sub>i</sub>:
# ```python
# k = ind[0]
# ind2 = np.argsort(np.abs(np.multiply(SVM.coef_[0], bagOfWordsTest[k].todense()))).reshape(-1,1)
# s = 0
# for i in range((bagOfWordsTest[k]!=0).sum()):
#     ii = ind2[-i-1].item()
#     print('wi='+str(SVM.coef_[0][ii]), 'xi='+str(bagOfWordsTest[k,ii]),  vocabulary[ii])
#     s += SVM.coef_[0][ii]*bagOfWordsTest[k,ii]
# print('Проверка:',s)
# ```

# %%
prediction = SVM.decision_function(bagOfWordsTest)
margins = np.multiply(prediction, data.loc[50000:]['Sentiment'].to_numpy())
ind = np.argsort(margins)
i = ind[-1] + 50000
print('Величина выступа = ', margins[ind[-1]])
print('Величина предсказания = ', prediction[ind[-1]])
print('Сентиментность отзыва = ', data.loc[i,'Sentiment'])
print('\n')
print(data.loc[i,'Text'])
print("\n")
i = ind[0] + 50000
print('Величина выступа = ', margins[ind[0]])
print('Величина предсказания = ', prediction[ind[0]])
print('Сентиментность отзыва = ', data.loc[i,'Sentiment'])
print('\n')
print(data.loc[i,'Text'])
# Out:
# Величина выступа =  13.0131205349136
# Величина предсказания =  13.0131205349136
# Сентиментность отзыва =  1
#
#
# Иногда, когда смотришь из окна дома на ночной город с его бесконечными дорогами, освещающими пути и переходы фонарями, мигающими светофорами и рекламными вывесками, сверкающими неоновыми огнями, то мысленно восторгаешься красотой, загадочностью и таинственностью открывающегося вида. Ведь ты абсолютно не знаешь куда спешат те редкие в это время суток прохожие - кто-то возвращается из кино, кто-то припозднился на работе и усталыми шагами следует домой, кто-то идет на свидание заранее предвкушая радость встречи, а кто-то просто ловит случайное такси, которое этой ночью совершит наверное свой самый страшный маршрут. А что если очередной пассажир севший на заднее сидение машины, профессиональный киллер, который собирается осуществить за определенный промежуток времени целых пять убийств? Он очень умен, хладнокровен и бесконечно хитер, и следует заранее посочувствовать водителю такси, ибо ему придется стать свидетелем жестоких убийц, - и не факт, что сам он при этом останется в живых. Вышеперечисленные размышления могут быть плодом разыгравшегося на ночь глядя воображения, или действительно иметь реальную основу, но в данном контексте, речь идет наверное о самом интересном триллере последнего десятилетия, который носит короткое название - «Соучастник». В этой картине нам предстоит погрузиться в историю простого таксиста Макса, которому отнюдь не посчастливилось подобрать в один прекрасный вечер настоящего наемного убийцу. И тут, мы становимся уже не простыми фантазерами наблюдающими из окна собственного дома за происходящим на ночной улице и воображающими на сон грядущий бог знает что, а настоящими свидетелями увлекательных злоключений, которые покажет нам замечательная картина Майкла Манна. «Соучастник», весьма нестандартный триллер. В нем не так уж и много погонь, стрельбы и прочих атрибутов жанра. Присутствующие в картине перестрелки и преследования возникают именно тогда, когда они необходимы, и от того, смотрятся до боли тонко и органично. Манн не пытается удивить зрителя особыми экшен эпизодами и не превращает свое творение в одноразовую развлекаловку с бесконечными взрывами и спецэффектами. Вместо этого он изобретательно выстраивает саспенс за счет увлекательной концепции и ловко акцентирует внимание на конфликте главных героев. Вернее главного дуэта, который составляют Джейми Фокс и Том Круз. Первый играет водителя такси, который уже очень долго планирует открыть свой собственный бизнес, хотя понимает, что эти его планы всего лишь отмазка для того, чтобы прикрыть свою нерешительность и страх перед переменами жизни. А второй, чуть ли не впервые за свою карьеру примеряет на себя маску отрицательного персонажа и воплощает на экране эксцентричного Винсента - беспощадного наемного убийцу, для которого жизнь человека ничего не стоит. Оба настолько замечательно смотрятся в своих ролях, что пожалуй их великолепный дуэт запомнится надолго. Противостояние Макса и Винсента очень многогранно - тут присутствует и симпатия, и ненависть, и злоба, и полное непонимание. Макс по-настоящему приходит в шок, когда осознает, что на заднем сидении его такси сидит убийца - он растерян и одновременно поражен беспощадностью Винсента. Тот в свое время равнодушно констатирует то, что ежедневно в мире убивают тысячу людей и ему странно, что на этого водилу произвела такое впечатление смерть жителя Лос-Анджелеса - в этом городе всем плевать друг на друга и даже если в метро будет лежать труп человека, то никто даже и не обратит на него внимание, а остывшее тело в это время целые сутки будет наматывать круги в полупустом вагоне - «Это моя работа Макс!» Нельзя сказать, что Манн симпатизирует герою Круза, скорее он показывает человека-убийцу, которого ненароком породило общество зачастую жестокое, продажное и да, абсолютно равнодушное друг к другу. Напротив Макс - это образец обычного неудачника с доброй душой и с очень нерешительным и даже трусливым характером, который тоже является частью системы, только на которого оная сказывается совсем по другому. Мак ...
#
#
# Величина выступа =  -6.730636847041421
# Величина предсказания =  6.730636847041421
# Сентиментность отзыва =  -1
#
#
# Замах и исполнение «Интерстеллара» воистину галактические. Но драматургия местами предсказуемая, а финал настолько приторный, будто бы ты три часа провел в космосе, постоянно посасывая сгущенку из железной тубы астронавта. Одиозный, неоднозначный, общепризнанный Тарантино как-то сказал: «мне нравится думать, что все мои фильмы от первого до последнего будут связаны своеобразной пуповиной», то есть так, чтобы всех их соединяла тонкая, едва видимая нить. Кажется, Кристофер Нолан, этой идей проникся, может быть, ее никогда и не слышав. Но, представляется, что до конца ее реализовать он все-таки не смог, даже принимая во внимание всю глубину его таланта. Почему «Интерстеллар» так ждали? Потому что Нолан создал реноме мыслителя от Голливуда - режиссера, который за абсолютно «блокбастерским» видеорядом плел совершенно не характерную современному американскому кинематографу паутину философского подтекста, разгадать которую удавалось и рядовому зрителю любого континента, что является неимоверной его заслугой. Доступность же эта совершенно не отменяет и не умаляет ни глубину заданных вопросов, ни метафоричность данных ответов. Так было в уникальной постановке Бэтмана по мотивам «попсового» комикса. Он у Кристофера Нолана стал «Темным рыцарем» - неоднозначным героем, уверенным в том, что человечество окончательно пало. Но, несмотря на это, абсолютно готический и слегка инфернальный в этой роли Кристиан Бэйл (особенно, сравнивая с гламурным Клуни) самозабвенно защищает погрязший в грехе Готэм. Он жертвует дружбой и даже любовью, чтобы спасти этот жалкий город, но, в результате, во всех сериях трилогии сталкивается с волной осуждения и неприятия, чем активно пользуются его злейшие враги, самым ярким из которых является ставший каноническим Джокер в исполнении безвременно скончавшегося Хита Леджера. Он смог сделать столько злодейств только потому, что четко осознал и виртуозно сыграл на всей низости человеческого существа, величине которого противопоставить что-либо практически не реально. Трилогия Нолана про героя-летучую мышь, пожалуй, стала одним из открытий в жанре экшн 2000-х годов, серьезной драмой в примитивных декорациях боевика, кстати говоря, большинством поклонников комиксов не оцененная. То же можно сказать и о камерном «Престиже» - фильме о конфликте выдающихся иллюзионистов, раскрывающем потаенные низменные чувства, вступающие во вполне очевидный конфликт с образами уникально талантливых фокусников, коими являются герои картины. В довершении, нельзя не сказать и о «Начале». С английского название этого фильма правильнее было бы перевести, как «Зарождение», и, представляется, что это то самое зарождение экшна за 160 млн$ с такой серьезной постановкой, что бедный Леонардо Ди Каприо по собственному, надо сказать, признанию после завершения съемок лечился в психиатрической больнице - настолько Нолан увлек его, а вместе с ним и зрителей идеей безразмерной, многослойной параллельной реальности. Несмотря на открытый финал этого культового кино, не остается ни малейшего сомнения, что эта самая реальность есть, пускай, она и живет в сознании режиссера. К сожалению, всего этого нельзя сказать об «Интерстелларе». Не стоит он ни всех многочисленных дифирамб, ни тех же в соотношении с «Началом» 165 млн$, а самое главное, не стоит того времени, которое мы неминуемо потратим на его просмотр. Но, несмотря на провокационный для сегодняшнего ритма жизни хронометраж в неполные 3 часа, обязательно найдутся люди, которые сходят на эту эпопею раз пять. В США вообще можно купить абонемент на этот фильм. Обязательно будут те, которые увидят в этой ленте громадную задумку, сотни философских изречений и научно-популярный аспект, по которому, кстати, и вправду соскучились. Да, они есть. Но все эти разговоры героев о «сингулярности», «законах материи», «теории чёрной дыры с аккреционным диском» - просто какой-то антураж, погремушки, звучащие более неестественно, чем звенящая тишина межпланетного вакуума или потрясающе громогласные исполинские волны на з ...

# %%
k = ind[0]
ind2 = np.argsort(np.abs(np.multiply(SVM.coef_[0], bagOfWordsTest[k].todense()))).reshape(-1,1)
s = 0
for i in range((bagOfWordsTest[k]!=0).sum()):
    ii = ind2[-i-1].item()
    print('wi='+str(SVM.coef_[0][ii]), 'xi='+str(bagOfWordsTest[k,ii]),  vocabulary[ii])
    s += SVM.coef_[0][ii]*bagOfWordsTest[k,ii]
print('Проверка:',s)
# Out:
# wi=0.381913028981906 xi=1 потрясающе
# wi=0.3751408256037174 xi=1 современному
# wi=-0.331722657946985 xi=1 позволения
# wi=-0.29714119169262293 xi=1 неестественно
# wi=0.28511997903781733 xi=1 остроумные
# wi=0.27305914612441046 xi=1 аспект
# wi=0.27301258665781 xi=1 фильм
# wi=0.2655146574092267 xi=1 слегка
# wi=0.256311549633102 xi=1 обязательно
# wi=-0.24718158865502418 xi=1 разговоры
# wi=0.24587879621653283 xi=1 действительность
# wi=0.2429022131716056 xi=1 закона
# wi=0.23885003819312672 xi=1 сегодняшнего
# wi=-0.23403831381464718 xi=1 абсолютно
# wi=-0.23400006082550973 xi=1 вывод
# wi=0.2333294246719182 xi=1 неоднозначный
# wi=-0.23321931432611578 xi=1 комикса
# wi=0.22653326398103726 xi=1 трилогии
# wi=0.22623919463690753 xi=1 научно
# wi=0.22617974827270326 xi=1 силе
# wi=0.22394184140310036 xi=1 родители
# wi=0.22347580103249232 xi=1 свежей
# wi=-0.22268417070473961 xi=1 очевидный
# wi=-0.2205084259044075 xi=1 полке
# wi=-0.2202737365248936 xi=1 сожалению
# wi=-0.21507924263219527 xi=1 философское
# wi=0.2143676188219839 xi=1 трилогия
# wi=-0.20866684525414242 xi=1 реализовать
# wi=-0.20739119518951668 xi=1 должна
# wi=0.20471107447856657 xi=1 вдвойне
# wi=0.2017349960785308 xi=1 комнате
# wi=0.19594641531341042 xi=1 безграничной
# wi=-0.1916216584666599 xi=1 создать
# wi=-0.19152827019809476 xi=1 сотни
# wi=0.18429111798522468 xi=1 мерфи
# wi=0.183859705350171 xi=1 живое
# wi=0.18138984771039496 xi=1 классика
# wi=0.1813729731708041 xi=1 несмотря
# wi=-0.17415381177044897 xi=1 дочкой
# wi=-0.17285783406290123 xi=1 весь
# wi=-0.17216853459014986 xi=1 леджера
# wi=0.17174555815550716 xi=1 перевести
# wi=0.1715780902484991 xi=1 очень
# wi=-0.16861277633081093 xi=1 спасти
# wi=0.16496092911506113 xi=1 сказал
# wi=-0.16430729853898607 xi=1 взглядом
# wi=0.16249221265649763 xi=1 погонями
# wi=0.1620640298209805 xi=1 важно
# wi=-0.1567741044288033 xi=1 драмой
# wi=0.15671141899066618 xi=1 культового
# wi=-0.15449065308835763 xi=1 излишняя
# wi=-0.15435574059776425 xi=1 окончательно
# wi=0.15295324055443743 xi=1 деталь
# wi=0.15248832213622532 xi=1 последнего
# wi=-0.15095752357702333 xi=1 творческом
# wi=0.15003407162443969 xi=1 жанра
# wi=0.14962738385464233 xi=1 четко
# wi=0.14879161717885628 xi=1 сходят
# wi=-0.14765889486901118 xi=1 совершенно
# wi=-0.14716603486451713 xi=1 знаки
# wi=-0.14675963038670733 xi=1 диалоги
# wi=-0.14636758011619905 xi=1 таланта
# wi=0.1455291315599812 xi=1 противостоять
# wi=0.14539068247463266 xi=1 реноме
# wi=0.1442914322224968 xi=1 глубине
# wi=0.14325039134035142 xi=1 очередь
# wi=-0.14189107471128204 xi=1 вообще
# wi=-0.14062745193657275 xi=1 идеи
# wi=0.13825889187353835 xi=1 главное
# wi=-0.13769579122533993 xi=1 престиже
# wi=-0.13655450967533792 xi=1 часа
# wi=-0.13615120933340902 xi=1 способна
# wi=-0.1360424795547887 xi=1 предсказуемая
# wi=0.1341989149311302 xi=1 видеорядом
# wi=-0.13395385864871387 xi=1 звучат
# wi=0.1319300075825491 xi=1 пускай
# wi=-0.13146503129827464 xi=1 открытый
# wi=0.13133507383335552 xi=1 философских
# wi=0.13095810403711053 xi=1 особенно
# wi=0.130122201738737 xi=1 американскому
# wi=0.1287699297684024 xi=1 любовью
# wi=0.1277089482870503 xi=1 планете
# wi=0.1268470316096692 xi=1 остроумными
# wi=-0.12381014855309629 xi=1 ждешь
# wi=-0.12283158957987171 xi=1 ответов
# wi=-0.11964370377414849 xi=1 поклонников
# wi=0.11906429069425528 xi=1 поздно
# wi=0.1189358136934438 xi=1 человечество
# wi=0.1186153390085385 xi=1 английского
# wi=0.11808321585229392 xi=1 именно
# wi=0.11782700778375871 xi=1 героя
# wi=-0.11663630232363509 xi=1 решил
# wi=0.11592124811173259 xi=1 зарождение
# wi=0.11506239751119032 xi=1 кино
# wi=0.11447528936884391 xi=1 голливуда
# wi=0.11338610885783956 xi=1 нить
# wi=0.11176302932361937 xi=1 вполне
# wi=0.11147158095794564 xi=1 уникально
# wi=0.11126246827108795 xi=1 своеобразной
# wi=-0.11084349070061406 xi=1 главного
# wi=-0.11019491903334941 xi=1 нолана
# wi=0.10988255293121216 xi=1 саги
# wi=0.10935083691414871 xi=1 готэм
# wi=0.10657400580361223 xi=1 многих
# wi=0.1063398022021717 xi=1 волны
# wi=0.10625419406605122 xi=1 ставший
# wi=0.10607609730735232 xi=1 логично
# wi=0.10573147589479823 xi=1 это
# wi=0.10467092824173051 xi=1 готический
# wi=0.10455525936109385 xi=1 пришельцев
# wi=0.10375677806263556 xi=1 самим
# wi=0.10374497875264876 xi=1 сознании
# wi=0.10358150779958948 xi=1 внедрить
# wi=-0.10355403745765028 xi=1 паутину
# wi=0.1029745325750104 xi=1 пафоса
# wi=0.10250872290871599 xi=1 глубину
# wi=0.10248770892766826 xi=1 тарантино
# wi=0.10165804042141466 xi=1 разгадать
# wi=-0.10119375181923118 xi=1 почему
# wi=-0.10113419908824331 xi=1 человечества
# wi=0.10092737144047811 xi=1 одноименном
# wi=-0.10018551582392116 xi=1 хита
# wi=-0.09929097774298737 xi=1 существа
# wi=-0.09906889282303435 xi=1 увидят
# wi=-0.09778870312605922 xi=1 получается
# wi=-0.09756819602973037 xi=1 общем
# wi=-0.09736032623482788 xi=1 представляется
# wi=0.09725397926524279 xi=1 семьи
# wi=-0.09695215658461795 xi=1 зрителю
# wi=-0.09681520119930057 xi=1 рыцарем
# wi=-0.09663383676253623 xi=1 пути
# wi=0.09582325596863325 xi=1 любовь
# wi=-0.09558396603002796 xi=1 коммерческой
# wi=-0.09550327088741739 xi=1 зрителей
# wi=0.09532369900899793 xi=1 формата
# wi=0.09468924426151362 xi=1 кристофер
# wi=0.09453283735199923 xi=1 внимание
# wi=0.09431944673558358 xi=1 баланса
# wi=0.09424420031627498 xi=1 город
# wi=0.0940375583104057 xi=1 серьезной
# wi=-0.09374412816935822 xi=1 мотивам
# wi=-0.09368656364673145 xi=1 хотел
# wi=-0.0923184461099208 xi=1 результате
# wi=0.09178008165754041 xi=1 вместе
# wi=-0.09156604506991461 xi=1 итоге
# wi=0.09106349451084247 xi=1 измерения
# wi=-0.09082966240875788 xi=1 найдутся
# wi=0.09059609553587258 xi=1 прекрасно
# wi=-0.08947859412355763 xi=1 получилось
# wi=0.08909180066383003 xi=1 активно
# wi=-0.08874812536095804 xi=1 талантливых
# wi=0.08815464338033357 xi=1 последние
# wi=-0.08776709737544558 xi=1 бэтмана
# wi=0.08770084228948186 xi=1 роли
# wi=-0.08768518341423759 xi=1 название
# wi=0.08765617927644107 xi=1 стал
# wi=-0.08729756318778618 xi=1 выходит
# wi=0.08681414072882322 xi=1 нолан
# wi=0.0857459992489104 xi=1 присутствуют
# wi=-0.08505365131883871 xi=1 фэнтази
# wi=-0.08418716922982959 xi=1 образами
# wi=-0.08413362962512859 xi=1 простому
# wi=0.08395893727610415 xi=1 последний
# wi=-0.08273836433681071 xi=1 мгла
# wi=0.08262504635444848 xi=1 купить
# wi=-0.08146527558878348 xi=1 сравнивая
# wi=-0.08095103567801741 xi=1 удавалось
# wi=0.08040097918219993 xi=1 остается
# wi=-0.07934077758700511 xi=1 правильнее
# wi=-0.07895380575489797 xi=1 представляются
# wi=0.07850000677130566 xi=1 драками
# wi=-0.07830543149074354 xi=1 успеха
# wi=0.07826881089307525 xi=1 неприятия
# wi=0.07774701138314635 xi=1 причиной
# wi=0.07761184701197762 xi=1 стоит
# wi=0.07743314023938583 xi=1 сыграл
# wi=-0.07738469519716909 xi=1 экшна
# wi=-0.07681248838250035 xi=1 кинематографу
# wi=0.07646367540331109 xi=1 красочности
# wi=0.0763925029071849 xi=1 параллельной
# wi=-0.07629925450644437 xi=1 зрителя
# wi=0.07617796841974879 xi=1 составляющие
# wi=0.07564333448097522 xi=1 случится
# wi=-0.07549976507040455 xi=1 большого
# wi=0.07478166516777535 xi=1 неминуемо
# wi=0.07461182094195139 xi=1 столько
# wi=0.07454379877645458 xi=1 декорациях
# wi=-0.07403060340258648 xi=1 беспросветная
# wi=-0.07392104256804002 xi=1 клуни
# wi=-0.07353073987028064 xi=1 неимоверной
# wi=-0.07304952690873626 xi=1 боевика
# wi=-0.07271657805513378 xi=1 призраками
# wi=-0.07259345844424378 xi=1 интерстеллар
# wi=-0.07181216618746013 xi=1 дружбой
# wi=0.07125040454976853 xi=1 дыры
# wi=-0.07124902977616707 xi=1 отыграны
# wi=0.0710125826201984 xi=1 грехе
# wi=-0.07089553627286914 xi=1 джорджа
# wi=0.07019246925862016 xi=1 природа
# wi=0.06999399536990357 xi=1 метафоричность
# wi=-0.06935131633167882 xi=1 похожа
# wi=-0.06931299863144046 xi=1 сделать
# wi=-0.06916061628290016 xi=1 принимая
# wi=0.06872764428232254 xi=1 ту
# wi=0.06819785432025122 xi=1 началом
# wi=0.06816988211134202 xi=1 стала
# wi=0.06792934602006019 xi=1 виртуозно
# wi=-0.06778761389618054 xi=1 идей
# wi=0.06757199533075668 xi=1 экипажа
# wi=0.06753263943102612 xi=1 малейшего
# wi=0.06735172586411985 xi=1 любого
# wi=0.0673387119766436 xi=1 постановкой
# wi=0.06716386081219212 xi=1 неприятность
# wi=-0.06713072734764922 xi=1 зрелищности
# wi=0.06696427751823764 xi=1 сага
# wi=0.06667980643014147 xi=1 защищает
# wi=-0.06662290065325233 xi=1 режиссера
# wi=-0.06621358764938266 xi=1 ди
# wi=0.06620339643286342 xi=1 высшая
# wi=-0.0660124080346035 xi=1 раса
# wi=0.06591942584732698 xi=1 повести
# wi=0.06588670678184055 xi=1 успешности
# wi=-0.06575588460880188 xi=1 книга
# wi=-0.06557141519234029 xi=1 коими
# wi=0.06486572615178436 xi=1 мои
# wi=0.06479531606011554 xi=1 верить
# wi=-0.06469458944140397 xi=1 шьямалана
# wi=-0.06463969047687318 xi=1 конфликт
# wi=0.06384414426221914 xi=1 становятся
# wi=-0.06362649036626963 xi=1 ждали
# wi=0.06352373549745358 xi=1 антураж
# wi=-0.061326529243481614 xi=1 ленте
# wi=0.06128368729682738 xi=1 хронометраж
# wi=-0.06110518989749094 xi=1 жертвует
# wi=0.06091577951828669 xi=1 психиатрической
# wi=0.06024695225503579 xi=1 реально
# wi=-0.06008333021257101 xi=1 план
# wi=0.05976147506844194 xi=1 подчеркивает
# wi=0.059101290689712635 xi=1 таки
# wi=-0.059047904508579135 xi=1 пять
# wi=0.0589251552758031 xi=1 героем
# wi=0.05892020123244393 xi=1 философского
# wi=0.05827654845208533 xi=1 ними
# wi=0.05817460600896661 xi=1 погрязший
# wi=0.058057369986237006 xi=1 глубины
# wi=0.05795543893521698 xi=1 кораблях
# wi=0.05757944072755429 xi=1 рано
# wi=-0.05753177417348078 xi=1 безвременно
# wi=0.05731141783279323 xi=1 стивена
# wi=0.05665850645515123 xi=1 конфликте
# wi=0.05646286109974143 xi=1 кристофера
# wi=-0.05637279806222294 xi=1 лишь
# wi=-0.05533605271973667 xi=1 неоднозначным
# wi=0.05467105698193958 xi=1 мышь
# wi=0.05450994184861645 xi=1 случиться
# wi=0.05442468124383981 xi=1 кинга
# wi=0.054059699136899196 xi=1 жизни
# wi=0.05392281751995909 xi=1 масштабности
# wi=0.05391335415391681 xi=1 джокер
# wi=0.0536802425449282 xi=1 десятилетия
# wi=-0.052023288768124995 xi=1 явлении
# wi=0.05199972483437293 xi=1 те
# wi=-0.051964085355260425 xi=1 постоянно
# wi=0.05165274398401784 xi=1 комиксов
# wi=0.051639491284919826 xi=1 воссоединения
# wi=-0.051203921078995844 xi=1 драматургия
# wi=0.051145490006950727 xi=1 больно
# wi=0.05113361016579348 xi=1 самыми
# wi=0.05108395463001798 xi=1 открытий
# wi=-0.05099556005192736 xi=1 годов
# wi=-0.050801186538501034 xi=1 соскучились
# wi=0.05060045218238338 xi=1 сериях
# wi=-0.050314793556123616 xi=1 потаенные
# wi=-0.04999960753857081 xi=1 приторный
# wi=0.049975083222782074 xi=1 слащавость
# wi=-0.04872083003332624 xi=1 скотта
# wi=0.048120541852715755 xi=1 космосе
# wi=0.04763930321252324 xi=1 амбиций
# wi=0.04728064530278991 xi=1 кажется
# wi=0.04703839439683372 xi=1 увлек
# wi=0.047005082970062555 xi=1 настоящему
# wi=-0.04679866266135644 xi=1 вправду
# wi=0.04674584741972299 xi=1 живет
# wi=0.04662347571459942 xi=1 нетривиальным
# wi=0.04652351921355564 xi=1 друг
# wi=0.04641144469980061 xi=1 любви
# wi=0.046355370066984584 xi=1 планомерно
# wi=0.04603042305126203 xi=1 расположена
# wi=-0.04594505988084817 xi=1 провел
# wi=0.045807781204130246 xi=1 этому
# wi=-0.045640305363760944 xi=1 низости
# wi=-0.04556215519737597 xi=1 американской
# wi=-0.04535278909483728 xi=1 тишина
# wi=-0.0449357370070889 xi=1 начале
# wi=-0.0447501743404998 xi=1 случилась
# wi=0.04474933098312528 xi=1 изречений
# wi=0.04454281851477515 xi=1 которую
# wi=0.044470751806110376 xi=1 нравится
# wi=0.044331446989154456 xi=1 своей
# wi=-0.043831968860422774 xi=1 данных
# wi=0.04337175281145038 xi=1 человеческого
# wi=0.04289385304509212 xi=1 исполнение
# wi=-0.04285368945463214 xi=1 будущего
# wi=0.0427136077499464 xi=1 тех
# wi=0.04236221117849898 xi=1 является
# wi=-0.04219148660958656 xi=1 отказался
# wi=0.04206931658848226 xi=1 излишнее
# wi=-0.041861584640962284 xi=1 самое
# wi=-0.041500545035058484 xi=1 диском
# wi=0.041466304059876155 xi=1 бедный
# wi=0.04135685422836774 xi=1 людям
# wi=0.04130939854075473 xi=1 сознательно
# wi=0.04079554079693467 xi=1 эта
# wi=0.04017059882116765 xi=1 популярный
# wi=0.039441591251851454 xi=1 говоря
# wi=-0.03939728203806398 xi=1 героев
# wi=0.03932514754008946 xi=1 макконахи
# wi=0.03916768153835632 xi=1 знаменитые
# wi=-0.03892648724808916 xi=1 атмосферы
# wi=-0.03884668914803474 xi=1 воссоздать
# wi=0.038724242172644356 xi=1 другого
# wi=0.03855217650294508 xi=1 действительно
# wi=0.03765925177053251 xi=1 кадров
# wi=0.03746204000277281 xi=1 сталкивается
# wi=-0.03718710970108696 xi=1 всей
# wi=-0.03717240157549664 xi=1 другом
# wi=-0.03673332462452668 xi=1 пожалуй
# wi=0.036431039283685546 xi=1 большинством
# wi=0.03635156267312658 xi=1 умаляет
# wi=0.036348030945130325 xi=1 средства
# wi=-0.03632984733718557 xi=1 сомнения
# wi=0.03623508751468728 xi=1 угоду
# wi=-0.03598637581743762 xi=1 кристиан
# wi=0.03582412781063083 xi=1 большой
# wi=0.03541697893656211 xi=1 железной
# wi=0.03525053554983813 xi=1 фабулу
# wi=0.034876493343890466 xi=1 обреченного
# wi=-0.034826547995314684 xi=1 лукаса
# wi=-0.03368534462531526 xi=1 ленты
# wi=-0.03283875470658365 xi=1 вопросов
# wi=-0.032824804499313985 xi=1 останется
# wi=0.03278425948667691 xi=1 завершения
# wi=0.03262409142088628 xi=1 враги
# wi=-0.032285647598607914 xi=1 тонкая
# wi=-0.03205669650724912 xi=1 заслугой
# wi=-0.0319768676021891 xi=1 планетах
# wi=0.03162324099030168 xi=1 реальность
# wi=0.03158127328559247 xi=1 менее
# wi=0.03133365769896128 xi=1 материи
# wi=-0.031195323800628526 xi=1 первую
# wi=0.030795594843523198 xi=1 провокационный
# wi=0.030585544692804487 xi=1 сша
# wi=0.03010754707241426 xi=1 детей
# wi=0.02980880840469308 xi=1 будут
# wi=-0.029440349283894857 xi=1 иллюзионистов
# wi=-0.029430164953952842 xi=1 уйти
# wi=0.028725716929862657 xi=1 который
# wi=-0.028685694767183627 xi=1 герои
# wi=0.028613533893287194 xi=1 подтекста
# wi=0.027933386093768484 xi=1 летучую
# wi=0.02762195401566544 xi=1 просмотр
# wi=0.027263699668303075 xi=1 значит
# wi=-0.0270064405692707 xi=1 которому
# wi=0.026448186549428338 xi=1 признанию
# wi=0.026357243002263733 xi=1 низменные
# wi=-0.026093134405816863 xi=1 книжной
# wi=0.025987209058179105 xi=1 жанре
# wi=0.025975996921660274 xi=1 доступность
# wi=0.025699610343547473 xi=1 волной
# wi=-0.025496092799736445 xi=1 каприо
# wi=0.02543887758074631 xi=1 первого
# wi=0.025428850314997427 xi=1 которые
# wi=0.025341153110934933 xi=1 антипатии
# wi=-0.025069870693279924 xi=1 обстоятельств
# wi=-0.024939432085733217 xi=1 едва
# wi=0.024892270583697508 xi=1 реальности
# wi=-0.024306319131146996 xi=1 думать
# wi=-0.023976778280124608 xi=1 отменяет
# wi=0.023880539657100616 xi=1 эпического
# wi=0.023745061684833826 xi=1 времени
# wi=-0.02364420516831015 xi=1 законах
# wi=0.02363454141932368 xi=1 постановке
# wi=0.02357928692176261 xi=1 расставания
# wi=0.023573328272519456 xi=1 кстати
# wi=-0.023085752136316088 xi=1 творческой
# wi=-0.022725912390555943 xi=1 проникся
# wi=0.02224393928536985 xi=1 создал
# wi=-0.021988574860545743 xi=1 практически
# wi=0.021668704144141144 xi=1 долгие
# wi=-0.021619300995040655 xi=1 которая
# wi=0.021593444298387793 xi=1 вашего
# wi=0.02142510243037349 xi=1 являются
# wi=0.020727732500751956 xi=1 изречение
# wi=0.020542072137855846 xi=1 млн
# wi=0.020370061075552524 xi=1 откроет
# wi=0.020333429705501123 xi=1 ритма
# wi=-0.019356367589222274 xi=1 уникальной
# wi=-0.01873932407747633 xi=1 осуждения
# wi=-0.018730823904874853 xi=1 самая
# wi=0.018514119246250873 xi=1 финальных
# wi=-0.018411037746991796 xi=1 прощания
# wi=0.018254891728756596 xi=1 второй
# wi=0.018032050054854844 xi=1 дочки
# wi=0.017978896043009528 xi=1 люди
# wi=0.017821009276276476 xi=1 самую
# wi=0.017473456401211455 xi=1 своих
# wi=0.016953055783360652 xi=1 больнице
# wi=-0.01674822220451742 xi=1 большим
# wi=-0.016434318802891822 xi=1 фильма
# wi=-0.01643351296756774 xi=1 просто
# wi=0.016339706785829158 xi=1 экшн
# wi=-0.0161656728816274 xi=1 черной
# wi=0.016013367803705266 xi=1 современного
# wi=-0.015990501016082848 xi=1 фильме
# wi=0.015270522836016116 xi=1 сказать
# wi=0.01501617868933681 xi=1 конца
# wi=0.014891999817817029 xi=1 подтверждением
# wi=-0.01488082319654623 xi=1 интерстеллара
# wi=-0.014759436375613427 xi=1 противопоставить
# wi=0.01471564086608396 xi=1 спасающих
# wi=0.01461538724726933 xi=1 самым
# wi=-0.01412667327112458 xi=1 самозабвенно
# wi=0.01373686925524007 xi=1 характерную
# wi=0.013627024587100587 xi=1 лучшие
# wi=-0.013528338404690298 xi=1 смог
# wi=-0.013224857318995318 xi=1 уверенным
# wi=0.013185819106379195 xi=1 исполнении
# wi=-0.01315244472798947 xi=1 картины
# wi=0.01277592989304156 xi=1 леонардо
# wi=0.012742730929349159 xi=1 соотношении
# wi=0.012407488682170068 xi=1 американского
# wi=0.011994439956289023 xi=1 либо
# wi=-0.011874051528802132 xi=1 бэйл
# wi=0.01185926672275157 xi=1 ярким
# wi=0.01131188583142763 xi=1 съемок
# wi=0.011111443722868378 xi=1 местами
# wi=-0.010960174389592825 xi=1 чувством
# wi=0.010904331509466413 xi=1 финал
# wi=0.01076202744865304 xi=1 роботы
# wi=-0.010591071221476327 xi=1 фильмы
# wi=-0.00993832332926359 xi=1 настолько
# wi=0.009219209861950349 xi=1 которых
# wi=-0.008986144234321682 xi=1 теории
# wi=-0.008901407862861777 xi=1 собственному
# wi=-0.008351609930444086 xi=1 повествования
# wi=0.008326078423887696 xi=1 многочисленных
# wi=-0.00827900442060848 xi=1 пользуются
# wi=0.008175548346032038 xi=1 связаны
# wi=-0.008159128678272882 xi=1 континента
# wi=-0.008050889649178678 xi=1 космической
# wi=-0.007662236980468274 xi=1 чутьем
# wi=-0.007523629968090865 xi=1 которое
# wi=0.007183477397470782 xi=1 одним
# wi=-0.006831806937220113 xi=1 фокусников
# wi=-0.00664912657833128 xi=1 астронавта
# wi=-0.006502216531288931 xi=1 примитивных
# wi=-0.006078146421630123 xi=1 автора
# wi=-0.0056246479942219305 xi=1 вю
# wi=-0.005614726812676801 xi=1 воистину
# wi=0.005153158946739472 xi=1 скорее
# wi=0.004057774111021743 xi=1 артефакт
# wi=-0.0036295557862895426 xi=1 стечению
# wi=0.0035919917722617755 xi=1 дарабонта
# wi=0.0035229975240571336 xi=1 выдающихся
# wi=-0.003192829566626722 xi=1 экспедиции
# wi=-0.0031121469680907747 xi=1 чувства
# wi=0.0026768793380461467 xi=1 рядовому
# wi=0.0024181733115105227 xi=1 задумку
# wi=-0.002358172571381591 xi=1 жалкий
# wi=-0.0023449270595829355 xi=1 нагнетание
# wi=-0.0020421339259606443 xi=1 эпизодов
# wi=-0.0020190732085588374 xi=1 осознал
# wi=0.0018749435413782417 xi=1 идеей
# wi=-0.0015040085195101565 xi=1 дежа
# wi=0.0008030635103922267 xi=1 темным
# wi=-0.000644807290598513 xi=1 звучащие
# wi=0.0006224638355595936 xi=1 самые
# wi=0.0006034866087092326 xi=1 эпопею
# wi=0.00046098593928849303 xi=1 которого
# wi=-0.00032360158862893094 xi=1 триумфального
# wi=-0.00025843898548906746 xi=1 убедительнее
# Проверка: 6.730636847041417

# %% [markdown]
# Нормализуйте признаки перед разбиением выборки на Train и Test так, чтобы вместо 0/1 стояли частоты употребления слов, деленные на длину отзыва. Подберите наилучшую константу C и опишите, как изменятся отзывы с минимальным и максимальным выступом? Что лучше: не нормализованные или нормализованные признаки? Почему?
#
# Нужно установить binary = False в CountVectorizer и добавить после fit_transform
# ```python
# bagOfWords = preprocessing.normalize(bagOfWords, norm='l1')
# ```

# %%
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, stop_words = None, max_features = 50000, binary = False)
bagOfWords = vectorizer.fit_transform(data2.Text)
bagOfWords = preprocessing.normalize(bagOfWords, norm='l1')
print(bagOfWords)
# Out:
#   (0, 20)	0.011194029850746268
#   (0, 414)	0.0037313432835820895
#   (0, 2557)	0.0037313432835820895
#   (0, 2767)	0.0037313432835820895
#   (0, 2927)	0.0037313432835820895
#   (0, 3199)	0.0037313432835820895
#   (0, 3320)	0.0037313432835820895
#   (0, 3640)	0.0037313432835820895
#   (0, 4076)	0.0037313432835820895
#   (0, 4106)	0.0037313432835820895
#   (0, 4490)	0.0037313432835820895
#   (0, 4689)	0.0037313432835820895
#   (0, 5315)	0.0037313432835820895
#   (0, 5379)	0.0037313432835820895
#   (0, 5404)	0.007462686567164179
#   (0, 5433)	0.0037313432835820895
#   (0, 5647)	0.0037313432835820895
#   (0, 5737)	0.0037313432835820895
#   (0, 5872)	0.0037313432835820895
#   (0, 6164)	0.0037313432835820895
#   (0, 6380)	0.0037313432835820895
#   (0, 6517)	0.0037313432835820895
#   (0, 6546)	0.0037313432835820895
#   (0, 6772)	0.0037313432835820895
#   (0, 6825)	0.0037313432835820895
#   :	:
#   (99999, 47606)	0.0018656716417910447
#   (99999, 47643)	0.0037313432835820895
#   (99999, 47792)	0.0018656716417910447
#   (99999, 47942)	0.0018656716417910447
#   (99999, 48051)	0.0018656716417910447
#   (99999, 48065)	0.0037313432835820895
#   (99999, 48236)	0.0018656716417910447
#   (99999, 48309)	0.0018656716417910447
#   (99999, 48401)	0.0018656716417910447
#   (99999, 48427)	0.0037313432835820895
#   (99999, 48440)	0.0018656716417910447
#   (99999, 48598)	0.0018656716417910447
#   (99999, 48835)	0.0018656716417910447
#   (99999, 48846)	0.0018656716417910447
#   (99999, 48897)	0.0018656716417910447
#   (99999, 49224)	0.0018656716417910447
#   (99999, 49229)	0.0018656716417910447
#   (99999, 49571)	0.0018656716417910447
#   (99999, 49572)	0.0037313432835820895
#   (99999, 49574)	0.0037313432835820895
#   (99999, 49657)	0.0018656716417910447
#   (99999, 49660)	0.018656716417910446
#   (99999, 49762)	0.0018656716417910447
#   (99999, 49822)	0.0018656716417910447
#   (99999, 49934)	0.0018656716417910447
